# %% [markdown]
# # Data Cleaning

# %%
# Read in the data
import pandas as pd

df = pd.read_csv('/content/UConn_SJI_Data_.csv')
df.head()
# Out:
#    Participant                Timestamp  Group ID                 Institution  \
# 0          126  2024-09-26 14:18:12.405  no group  University Of Connecticut
# 1          127  2024-09-27 22:57:00.168  no group                       Uconn
# 2          128  2024-09-28 15:54:21.361  BRIDGE24   University of Connecticut
# 3          129  2024-09-28 19:30:01.827  BRIDGE24  University of Connecticut
# 4          130  2024-09-28 19:56:19.767  BRIDGE24   University of Connecticut
#
#   S1 (Least Likely)\n\nYour first round of tests did not go well and your usual studying habits are not working  \
# 0  Make and work with a study group with peers in...
# 1  Wait until the next round of tests to see if y...
# 2  Visit the student success center to learn a ne...
# 3  Wait until the next round of tests to see if y...
# 4  Wait until the next round of tests to see if y...
#
#   S1 (Most Likely) \n\nYour first round of tests did not go well and your usual studying habits are not working  \
# ...
